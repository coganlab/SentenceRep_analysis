# %%
# Description: Check channels for outliers and remove them
from ieeg.viz.utils import chan_grid
from ieeg.viz.parula import parula_map
from ieeg.io import get_data, raw_from_layout, update
from ieeg.navigate import trial_ieeg, channel_outlier_marker, crop_empty_data
from ieeg.calc.scaling import rescale
from ieeg.calc.stats import avg_no_outlier, find_outliers
import mpld3
import pickle
import os
from mne.time_frequency import tfr_morlet
from ieeg.timefreq.utils import wavelet_scaleogram
import numpy as np

# %% check if currently running a slurm job
HOME = os.path.expanduser("~")
if 'SLURM_ARRAY_TASK_ID' in os.environ.keys():
    LAB_root = os.path.join(HOME, "workspace", "CoganLab")
    subject = int(os.environ['SLURM_ARRAY_TASK_ID'])
else:  # if not then set box directory
    LAB_root = os.path.join(HOME, "Box", "CoganLab")
    subject = 3

# Load the data
TASK = "SentenceRep"
subj = "D" + str(subject).zfill(4)
layout = get_data("SentenceRep", root=LAB_root)
filt = raw_from_layout(layout.derivatives['clean'], subject=subj,
                       extension='.edf', desc='clean', preload=False)
# Out:
# Extracting EDF parameters from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-01_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-01_desc-clean_events.tsv.
# Reading channel info from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-01_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-02_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-02_desc-clean_events.tsv.
# Reading channel info from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-02_desc-clean_channels.tsv.
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: The number of channels in the channels.tsv sidecar file (53) does not match the number of channels in the raw data file (52). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Omitted 163 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# Reading electrode coords from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-03_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-03_desc-clean_events.tsv.
# Reading channel info from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-03_desc-clean_channels.tsv.
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: The number of channels in the channels.tsv sidecar file (53) does not match the number of channels in the raw data file (52). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Omitted 166 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# Reading electrode coords from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-04_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: The number of channels in the channels.tsv sidecar file (53) does not match the number of channels in the raw data file (52). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# Reading events from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-04_desc-clean_events.tsv.
# Reading channel info from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-04_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_acq-01_space-ACPC_electrodes.tsv.
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: The number of channels in the channels.tsv sidecar file (53) does not match the number of channels in the raw data file (52). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path)
# C:\Users\Jakda\git\SentenceRep_analysis\ieeg\io.py:98: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path)

# %%
# %% fix SentenceRep events
from events import fix_annotations  # noqa E402
new = crop_empty_data(filt,)

good = new.copy()
fix_annotations(good)
# Out:
# Condition 42 and 43 co-occur
# Early response condition 79
# Condition 81 and 82 co-occur
# Condition 90 and 91 co-occur
# Condition 182 and 183 co-occur
# Condition 269 and 270 co-occur
# Condition 301 and 302 co-occur
# Condition 304 and 305 co-occur
# Condition 406 and 407 co-occur
# Speak cue not found for condition #453 Listen
# Condition 472 and 473 co-occur
# Condition 555 and 556 co-occur
# Condition 579 and 580 co-occur
# Condition 622 and 623 co-occur
# Condition 636 and 637 co-occur
# [79, 128, 131, 152, 226, 263, 319, 383, 389, 400, 436, 453, 457, 531]

# %%
# %% Crop raw data to minimize processing time

# good.drop_channels(good.info['bads'])
good.info['bads'] += channel_outlier_marker(good, 3, 2, save=True)
good.drop_channels(good.info['bads'])
# good.info['bads'] += channel_outlier_marker(good, 4, 2)
# good.drop_channels(good.info['bads'])
good.load_data()

ch_type = filt.get_channel_types(only_data_chs=True)[0]
good.set_eeg_reference(ref_channels="average", ch_type=ch_type)

# Remove intermediates from mem
del new
# good.plot()
# Out:
# outlier round 1 channels: ['LTG12']
# outlier round 2 channels: ['LTG12', 'LTG9']
# Processing channel LTG12:
#     status: bad
#     description: outlier round 1 more than 3 SDs above mean
# Processing channel LTG9:
#     status: bad
#     description: outlier round 2 more than 3 SDs above mean
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-01_desc-clean_channels.tsv'...
# Processing channel LTG1:
#     status: bad
#     description: None
# Processing channel LTG2:
#     status: bad
#     description: None
# Processing channel LTG3:
#     status: bad
#     description: None
# Processing channel LTG4:
#     status: bad
#     description: None
# Processing channel LTG5:
#     status: bad
#     description: None
# Processing channel LTG6:
#     status: bad
#     description: None
# Processing channel LTG7:
#     status: bad
#     description: None
# Processing channel LTG8:
#     status: bad
#     description: None
# Processing channel LTG10:
#     status: bad
#     description: None
# Processing channel LTG11:
#     status: bad
#     description: None
# Processing channel LTG13:
#     status: bad
#     description: None
# Processing channel LTG14:
#     status: bad
#     description: None
# Processing channel LTG15:
#     status: bad
#     description: None
# Processing channel LTG16:
#     status: bad
#     description: None
# Processing channel LTG17:
#     status: bad
#     description: None
# Processing channel LTG18:
#     status: bad
#     description: None
# Processing channel LTG19:
#     status: bad
#     description: None
# Processing channel LTG20:
#     status: bad
#     description: None
# Processing channel LTG21:
#     status: bad
#     description: None
# Processing channel LTG22:
#     status: bad
#     description: None
# Processing channel LTG23:
#     status: bad
#     description: None
# Processing channel LTG24:
#     status: bad
#     description: None
# Processing channel LTG25:
#     status: bad
#     description: None
# Processing channel LTG26:
#     status: bad
#     description: None
# Processing channel LTG27:
#     status: bad
#     description: None
# Processing channel LTG28:
#     status: bad
#     description: None
# Processing channel LTG29:
#     status: bad
#     description: None
# Processing channel LTG30:
#     status: bad
#     description: None
# Processing channel LTG31:
#     status: bad
#     description: None
# Processing channel LTG32:
#     status: bad
#     description: None
# Processing channel LOF1:
#     status: bad
#     description: None
# Processing channel LOF2:
#     status: bad
#     description: None
# Processing channel LOF3:
#     status: bad
#     description: None
# Processing channel LOF4:
#     status: bad
#     description: None
# Processing channel LTP1:
#     status: bad
#     description: None
# Processing channel LTP2:
#     status: bad
#     description: None
# Processing channel LTP3:
#     status: bad
#     description: None
# Processing channel LTP4:
#     status: bad
#     description: None
# Processing channel LAST1:
#     status: bad
#     description: None
# Processing channel LAST2:
#     status: bad
#     description: None
# Processing channel LAST3:
#     status: bad
#     description: None
# Processing channel LAST4:
#     status: bad
#     description: None
# Processing channel LMST1:
#     status: bad
#     description: None
# Processing channel LMST2:
#     status: bad
#     description: None
# Processing channel LMST3:
#     status: bad
#     description: None
# Processing channel LMST4:
#     status: bad
#     description: None
# Processing channel LPST1:
#     status: bad
#     description: None
# Processing channel LPST2:
#     status: bad
#     description: None
# Processing channel LPST3:
#     status: bad
#     description: None
# Processing channel LPST4:
#     status: bad
#     description: None
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-01_desc-clean_channels.tsv'...
# Processing channel LTG12:
#     status: bad
#     description: outlier round 1 more than 3 SDs above mean
# Processing channel LTG9:
#     status: bad
#     description: outlier round 2 more than 3 SDs above mean
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-02_desc-clean_channels.tsv'...
# Processing channel LTG1:
#     status: bad
#     description: None
# Processing channel LTG2:
#     status: bad
#     description: None
# Processing channel LTG3:
#     status: bad
#     description: None
# Processing channel LTG4:
#     status: bad
#     description: None
# Processing channel LTG5:
#     status: bad
#     description: None
# Processing channel LTG6:
#     status: bad
#     description: None
# Processing channel LTG7:
#     status: bad
#     description: None
# Processing channel LTG8:
#     status: bad
#     description: None
# Processing channel LTG10:
#     status: bad
#     description: None
# Processing channel LTG11:
#     status: bad
#     description: None
# Processing channel LTG13:
#     status: bad
#     description: None
# Processing channel LTG14:
#     status: bad
#     description: None
# Processing channel LTG15:
#     status: bad
#     description: None
# Processing channel LTG16:
#     status: bad
#     description: None
# Processing channel LTG17:
#     status: bad
#     description: None
# Processing channel LTG18:
#     status: bad
#     description: None
# Processing channel LTG19:
#     status: bad
#     description: None
# Processing channel LTG20:
#     status: bad
#     description: None
# Processing channel LTG21:
#     status: bad
#     description: None
# Processing channel LTG22:
#     status: bad
#     description: None
# Processing channel LTG23:
#     status: bad
#     description: None
# Processing channel LTG24:
#     status: bad
#     description: None
# Processing channel LTG25:
#     status: bad
#     description: None
# Processing channel LTG26:
#     status: bad
#     description: None
# Processing channel LTG27:
#     status: bad
#     description: None
# Processing channel LTG28:
#     status: bad
#     description: None
# Processing channel LTG29:
#     status: bad
#     description: None
# Processing channel LTG30:
#     status: bad
#     description: None
# Processing channel LTG31:
#     status: bad
#     description: None
# Processing channel LTG32:
#     status: bad
#     description: None
# Processing channel LOF1:
#     status: bad
#     description: None
# Processing channel LOF2:
#     status: bad
#     description: None
# Processing channel LOF3:
#     status: bad
#     description: None
# Processing channel LOF4:
#     status: bad
#     description: None
# Processing channel LTP1:
#     status: bad
#     description: None
# Processing channel LTP2:
#     status: bad
#     description: None
# Processing channel LTP3:
#     status: bad
#     description: None
# Processing channel LTP4:
#     status: bad
#     description: None
# Processing channel LAST1:
#     status: bad
#     description: None
# Processing channel LAST2:
#     status: bad
#     description: None
# Processing channel LAST3:
#     status: bad
#     description: None
# Processing channel LAST4:
#     status: bad
#     description: None
# Processing channel LMST1:
#     status: bad
#     description: None
# Processing channel LMST2:
#     status: bad
#     description: None
# Processing channel LMST3:
#     status: bad
#     description: None
# Processing channel LMST4:
#     status: bad
#     description: None
# Processing channel LPST1:
#     status: bad
#     description: None
# Processing channel LPST2:
#     status: bad
#     description: None
# Processing channel LPST3:
#     status: bad
#     description: None
# Processing channel LPST4:
#     status: bad
#     description: None
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-02_desc-clean_channels.tsv'...
# Processing channel LTG12:
#     status: bad
#     description: outlier round 1 more than 3 SDs above mean
# Processing channel LTG9:
#     status: bad
#     description: outlier round 2 more than 3 SDs above mean
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-03_desc-clean_channels.tsv'...
# Processing channel LTG1:
#     status: bad
#     description: None
# Processing channel LTG2:
#     status: bad
#     description: None
# Processing channel LTG3:
#     status: bad
#     description: None
# Processing channel LTG4:
#     status: bad
#     description: None
# Processing channel LTG5:
#     status: bad
#     description: None
# Processing channel LTG6:
#     status: bad
#     description: None
# Processing channel LTG7:
#     status: bad
#     description: None
# Processing channel LTG8:
#     status: bad
#     description: None
# Processing channel LTG10:
#     status: bad
#     description: None
# Processing channel LTG11:
#     status: bad
#     description: None
# Processing channel LTG13:
#     status: bad
#     description: None
# Processing channel LTG14:
#     status: bad
#     description: None
# Processing channel LTG15:
#     status: bad
#     description: None
# Processing channel LTG16:
#     status: bad
#     description: None
# Processing channel LTG17:
#     status: bad
#     description: None
# Processing channel LTG18:
#     status: bad
#     description: None
# Processing channel LTG19:
#     status: bad
#     description: None
# Processing channel LTG20:
#     status: bad
#     description: None
# Processing channel LTG21:
#     status: bad
#     description: None
# Processing channel LTG22:
#     status: bad
#     description: None
# Processing channel LTG23:
#     status: bad
#     description: None
# Processing channel LTG24:
#     status: bad
#     description: None
# Processing channel LTG25:
#     status: bad
#     description: None
# Processing channel LTG26:
#     status: bad
#     description: None
# Processing channel LTG27:
#     status: bad
#     description: None
# Processing channel LTG28:
#     status: bad
#     description: None
# Processing channel LTG29:
#     status: bad
#     description: None
# Processing channel LTG30:
#     status: bad
#     description: None
# Processing channel LTG31:
#     status: bad
#     description: None
# Processing channel LTG32:
#     status: bad
#     description: None
# Processing channel LOF1:
#     status: bad
#     description: None
# Processing channel LOF2:
#     status: bad
#     description: None
# Processing channel LOF3:
#     status: bad
#     description: None
# Processing channel LOF4:
#     status: bad
#     description: None
# Processing channel LTP1:
#     status: bad
#     description: None
# Processing channel LTP2:
#     status: bad
#     description: None
# Processing channel LTP3:
#     status: bad
#     description: None
# Processing channel LTP4:
#     status: bad
#     description: None
# Processing channel LAST1:
#     status: bad
#     description: None
# Processing channel LAST2:
#     status: bad
#     description: None
# Processing channel LAST3:
#     status: bad
#     description: None
# Processing channel LAST4:
#     status: bad
#     description: None
# Processing channel LMST1:
#     status: bad
#     description: None
# Processing channel LMST2:
#     status: bad
#     description: None
# Processing channel LMST3:
#     status: bad
#     description: None
# Processing channel LMST4:
#     status: bad
#     description: None
# Processing channel LPST1:
#     status: bad
#     description: None
# Processing channel LPST2:
#     status: bad
#     description: None
# Processing channel LPST3:
#     status: bad
#     description: None
# Processing channel LPST4:
#     status: bad
#     description: None
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-03_desc-clean_channels.tsv'...
# Processing channel LTG12:
#     status: bad
#     description: outlier round 1 more than 3 SDs above mean
# Processing channel LTG9:
#     status: bad
#     description: outlier round 2 more than 3 SDs above mean
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-04_desc-clean_channels.tsv'...
# Processing channel LTG1:
#     status: bad
#     description: None
# Processing channel LTG2:
#     status: bad
#     description: None
# Processing channel LTG3:
#     status: bad
#     description: None
# Processing channel LTG4:
#     status: bad
#     description: None
# Processing channel LTG5:
#     status: bad
#     description: None
# Processing channel LTG6:
#     status: bad
#     description: None
# Processing channel LTG7:
#     status: bad
#     description: None
# Processing channel LTG8:
#     status: bad
#     description: None
# Processing channel LTG10:
#     status: bad
#     description: None
# Processing channel LTG11:
#     status: bad
#     description: None
# Processing channel LTG13:
#     status: bad
#     description: None
# Processing channel LTG14:
#     status: bad
#     description: None
# Processing channel LTG15:
#     status: bad
#     description: None
# Processing channel LTG16:
#     status: bad
#     description: None
# Processing channel LTG17:
#     status: bad
#     description: None
# Processing channel LTG18:
#     status: bad
#     description: None
# Processing channel LTG19:
#     status: bad
#     description: None
# Processing channel LTG20:
#     status: bad
#     description: None
# Processing channel LTG21:
#     status: bad
#     description: None
# Processing channel LTG22:
#     status: bad
#     description: None
# Processing channel LTG23:
#     status: bad
#     description: None
# Processing channel LTG24:
#     status: bad
#     description: None
# Processing channel LTG25:
#     status: bad
#     description: None
# Processing channel LTG26:
#     status: bad
#     description: None
# Processing channel LTG27:
#     status: bad
#     description: None
# Processing channel LTG28:
#     status: bad
#     description: None
# Processing channel LTG29:
#     status: bad
#     description: None
# Processing channel LTG30:
#     status: bad
#     description: None
# Processing channel LTG31:
#     status: bad
#     description: None
# Processing channel LTG32:
#     status: bad
#     description: None
# Processing channel LOF1:
#     status: bad
#     description: None
# Processing channel LOF2:
#     status: bad
#     description: None
# Processing channel LOF3:
#     status: bad
#     description: None
# Processing channel LOF4:
#     status: bad
#     description: None
# Processing channel LTP1:
#     status: bad
#     description: None
# Processing channel LTP2:
#     status: bad
#     description: None
# Processing channel LTP3:
#     status: bad
#     description: None
# Processing channel LTP4:
#     status: bad
#     description: None
# Processing channel LAST1:
#     status: bad
#     description: None
# Processing channel LAST2:
#     status: bad
#     description: None
# Processing channel LAST3:
#     status: bad
#     description: None
# Processing channel LAST4:
#     status: bad
#     description: None
# Processing channel LMST1:
#     status: bad
#     description: None
# Processing channel LMST2:
#     status: bad
#     description: None
# Processing channel LMST3:
#     status: bad
#     description: None
# Processing channel LMST4:
#     status: bad
#     description: None
# Processing channel LPST1:
#     status: bad
#     description: None
# Processing channel LPST2:
#     status: bad
#     description: None
# Processing channel LPST3:
#     status: bad
#     description: None
# Processing channel LPST4:
#     status: bad
#     description: None
# Writing 'C:\Users\Jakda\Box\CoganLab\BIDS-1.3_SentenceRep\BIDS\derivatives\clean\sub-D0003\ieeg\sub-D0003_task-SentenceRep_acq-01_run-04_desc-clean_channels.tsv'...
# Reading 0 ... 3063633  =      0.000 ...  1531.816 secs...
# Applying average reference.
# Applying a custom ('ECoG',) reference.

# %%
# %% epoching and trial outlier removal

resp = trial_ieeg(good, "Response", (-1.5, 1.5), preload=True)
resp_gtrials = find_outliers(resp.get_data(), 10)
resp_func = lambda x: avg_no_outlier(x, keep=resp_gtrials)
# resp_avg = resp.average(None, resp_func)

base = trial_ieeg(good, "Start", (-1, 0.5), preload=True)
base_gtrials = find_outliers(base.get_data(), 10)
base_func = lambda x: avg_no_outlier(x, keep=base_gtrials)
# base_avg = base.average(None, base_func)
# scaled = rescale(resp, base, mode='zscore', copy=True, outliers=10)

# %% create spectrograms

resp_s = wavelet_scaleogram(resp, n_jobs=-2, decim=int(good.info['sfreq']/100))
resp_s.crop(tmin=-1, tmax=1)
base_s = wavelet_scaleogram(base, n_jobs=-2, decim=int(good.info['sfreq']/100))
base_s.crop(tmin=-0.5, tmax=0)

spec = rescale(resp_s, base_s, copy=True, mode='ratio',
               base_trials=base_gtrials)
spec_a = spec.average(resp_func, copy=True)
spec_a._data = np.log10(spec_a._data) * 20
# Out:
# Used Annotations descriptions: ['Sentence/Audio/JL', 'Sentence/Audio/LS', 'Sentence/Response/JL', 'Sentence/Response/LS', 'Sentence/Speak/LS', 'Start/:=:/JL', 'Start/Listen/LM', 'Start/Listen/LS', 'Word/Audio/JL', 'Word/Audio/LM', 'Word/Audio/LS', 'Word/Mime/LM', 'Word/Mime/LS', 'Word/Response/JL', 'Word/Response/LM', 'Word/Response/LS', 'Word/Speak/LS']
# Not setting metadata
# 82 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 82 events and 6001 original time points ...
# 3 bad epochs dropped
# Used Annotations descriptions: ['Sentence/Audio/JL', 'Sentence/Audio/LS', 'Sentence/Response/JL', 'Sentence/Response/LS', 'Sentence/Speak/LS', 'Start/:=:/JL', 'Start/Listen/LM', 'Start/Listen/LS', 'Word/Audio/JL', 'Word/Audio/LM', 'Word/Audio/LS', 'Word/Mime/LM', 'Word/Mime/LS', 'Word/Response/JL', 'Word/Response/LM', 'Word/Response/LS', 'Word/Speak/LS']
# Not setting metadata
# 205 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 205 events and 3001 original time points ...
# 1 bad epochs dropped
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-2)]: Done  11 tasks      | elapsed:   16.7s
# [Parallel(n_jobs=-2)]: Done  18 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:   39.0s
# [Parallel(n_jobs=-2)]: Done  43 out of  50 | elapsed:   43.6s remaining:    7.0s
# Not setting metadata
# [Parallel(n_jobs=-2)]: Done  50 out of  50 | elapsed:   46.5s finished
# [Parallel(n_jobs=-2)]: Using backend ThreadingBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-2)]: Done  11 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-2)]: Done  18 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-2)]: Done  27 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-2)]: Done  36 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-2)]: Done  43 out of  50 | elapsed:   32.7s remaining:    5.2s
# Not setting metadata
# [Parallel(n_jobs=-2)]: Done  50 out of  50 | elapsed:   35.3s finished
# Applying baseline correction (mode: ratio)
# Removed Trial 4 in Channel 42
# Removed Trial 11 in Channel 42
# Removed Trial 19 in Channel 42
# Removed Trial 23 in Channel 42
# Removed Trial 27 in Channel 42
# Removed Trial 28 in Channel 35
# Removed Trial 32 in Channel 42
# Removed Trial 44 in Channel 35
# Removed Trial 46 in Channel 35
# Removed Trial 46 in Channel 42
# Removed Trial 51 in Channel 35
# Removed Trial 52 in Channel 35
# Removed Trial 53 in Channel 10
# Removed Trial 59 in Channel 42
# Removed Trial 60 in Channel 35
# Removed Trial 61 in Channel 10
# Removed Trial 63 in Channel 42
# Removed Trial 65 in Channel 35
# Removed Trial 66 in Channel 42
# Removed Trial 68 in Channel 10
# Removed Trial 71 in Channel 10

# %%
# %% plotting

figs = chan_grid(spec_a, size=(16, 12), vmin=-2, vmax=2,
                 cmap=parula_map, show=False)

# %% [markdown]
# # Save figures

# %%
fig_path = os.path.join(layout.root, 'derivatives', 'figs', 'wavelet')
for i, f in enumerate(figs):
    f.savefig(os.path.join(fig_path, f'{subj}_response_{i + 1}'))
    # pickle the figure for later
    with open(os.path.join(fig_path, f'{subj}_response_{i + 1}.pkl'), 'wb'
              ) as file:
        pickle.dump(f, file)
    with open(os.path.join(fig_path, f'{subj}_response_{i + 1}.pkl'), 'rb'
              ) as file:
        f2 = pickle.load(file)
# html_fig = mpld3.fig_to_html(f)
# mpld3.show(html_fig)
# assert False

# %%
# %% save bad channels
# good.info['bads'] += spec.info['bads']
# update(good, "muscle")
f2.show()
# Out:
# <div id='f8d97519-deb7-47d7-a56c-a55fd9b03714'></div>
